# %% [markdown]
# <a href="https://colab.research.google.com/github/Alaaibrahim2/Alaa/blob/main/Sonar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow import keras

from sklearn.metrics import classification_report, confusion_matrix

# %%
df=pd.read_csv('sonar_dataset.csv',header=None)

# %%
df
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
df = df.rename(columns= {60:'output'})

# %%
X=df.drop(['output'],axis=1)
y=df['output']

# %%
y = pd.get_dummies(y, drop_first= True)
y.sample(5)
# Out:
#      R
# 122  0
# 126  0
# 184  0
# 9    1
# 12   1

# %%
y.value_counts()
# Out:
# R
# 0    111
# 1     97
# dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=10)

# %%
print("Size of X_train: ", len(X_train))
print("Size of X_test: ", len(X_test))
print("Size of y_train: ", len(y_train))
print("Size of y_test: ", len(y_test))
# Out:
# Size of X_train:  166
# Size of X_test:  42
# Size of y_train:  166
# Size of y_test:  42

# %%
model  = keras.Sequential([
    keras.layers.Dense(60, input_dim = 60, activation = 'relu'),
    keras.layers.Dropout(0.5),
    
    keras.layers.Dense(25, activation = 'relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(30, activation = 'relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(20, activation = 'relu'),
    
    keras.layers.Dense(1, activation = 'sigmoid')])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 60)                3660
#
#  dense_1 (Dense)             (None, 60)                3660
#
#  dense_2 (Dense)             (None, 60)                3660
#
#  dense_3 (Dense)             (None, 60)                3660
#
#  dense_4 (Dense)             (None, 1)                 61
#
# ...
# Total params: 14,701
# Trainable params: 14,701
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss ='binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=100, batch_size=10)
# Out:
# Epoch 1/100
# 17/17 [==============================] - 2s 3ms/step - loss: 0.6952 - accuracy: 0.5422
# Epoch 2/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.7086 - accuracy: 0.4819
# Epoch 3/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6791 - accuracy: 0.5241
# Epoch 4/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6810 - accuracy: 0.5843
# Epoch 5/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6571 - accuracy: 0.5783
# Epoch 6/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6900 - accuracy: 0.5361
# Epoch 7/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6837 - accuracy: 0.5843
# Epoch 8/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6639 - accuracy: 0.5783
# Epoch 9/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6669 - accuracy: 0.5422
# Epoch 10/100
# ...

# %%
model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=100, batch_size=16)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-6aebbfff0ace> in <module>
# ----> 1 model.fit(x_train, y_train, epochs=100, batch_size=16)
#
# NameError: name 'x_train' is not defined
